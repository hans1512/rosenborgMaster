# %%
import cv2
import numpy as np
from pathlib import Path
from boxmot import DeepOCSORT, StrongSORT, BoTSORT
from ultralytics import YOLO
from pathlib import Path

# %%
def initialize_tracker(model_weights, device='cuda:0', fp16=True):
    """
    Initialize the DeepOCSORT tracker with the given model weights and device.
    """
    tracker = BoTSORT(
        model_weights=model_weights,
        device=device,
        fp16=fp16
    )
    return tracker

def initialize_yolo(model_path):
    """
    Initialize the YOLO object detector with the given model path.
    """
    yolov8 = YOLO(model_path)
    return yolov8

# %%
class Rect:
    def __init__(self, x1, y1, x2, y2):
        self.x1 = x1
        self.y1 = y1
        self.x2 = x2
        self.y2 = y2
    
    @property
    def bottom_center(self):
        return ((self.x1 + self.x2) // 2, self.y2)
    
    @property
    def width(self):
        return self.x2 - self.x1

class Color:
    def __init__(self, b, g, r):
        self.b = b
        self.g = g
        self.r = r

    @property
    def bgr_tuple(self):
        return (self.b, self.g, self.r)

def draw_ellipse(image, rect, color, thickness=2):
    center = rect.bottom_center
    axes = (int(rect.width), int(0.35 * rect.width))
    cv2.ellipse(
        image,
        center,
        axes,
        angle=0.0,
        startAngle=-45,
        endAngle=235,
        color=color.bgr_tuple,
        thickness=thickness,
        lineType=cv2.LINE_4
    )
    return image

def lab_to_rgb(lab_color):
    """
    Converts a single LAB color to RGB.
    """
    lab_image = np.array([[lab_color]], dtype=np.uint8)
    rgb_image = cv2.cvtColor(lab_image, cv2.COLOR_Lab2RGB)
    return rgb_image[0][0]

def create_new_file(file_name):
    """
    Check if a file already exists, if it does append a number to the file
    The number increases if a file_"number" exists
    """
    if Path(file_name).is_file():
        file = file_name.split(".")[0]
        extension = file_name.split(".")[1]
        last_char = file[len(file) - 1]
        if last_char.isnumeric():
            last_char = str(int(last_char) + 1)
            new_file =  file[:-1] + last_char + "." + extension
        else:
            last_char = "_1"
            new_file =  file + last_char + "." + extension
        
        return create_new_file(new_file)
    else:
        return file_name

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import sys
import sklearn
from collections import Counter


def adjust_bbox(image, bbox, height_fraction=(0.17, 0.5), width_fraction=(0.2, 0.2)):
    x1, y1, x2, y2 = bbox
    
    # Adjusting the bounding box to focus on the upper part
    height = y2 - y1
    width = x2 - x1
    
    new_y1 = y1 + int(height_fraction[0] * height)
    new_y2 = y1 + int(height_fraction[1] * height)
    new_x1 = x1 + int(width_fraction[0] * width)
    new_x2 = x2 - int(width_fraction[1] * width)

    adjusted_bbox = (new_x1, new_y1, new_x2, new_y2)
    roi = image[adjusted_bbox[1]:adjusted_bbox[3], adjusted_bbox[0]:adjusted_bbox[2]]

    return roi

def filter_out_color_LAB(roi_lab, lower_treshold, upper_treshold):
    # Getting the A channel and applying threshold
    a_channel = roi_lab[:,:,1]
    #127, 255
    _, mask = cv2.threshold(a_channel, lower_treshold, upper_treshold, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    # Using the mask to exclude green pixels in LAB
    roi_lab_filtered = roi_lab.copy()
    roi_lab_filtered[mask != 255] = 0
    return roi_lab_filtered

def get_color_histogram(image, bbox):
    """
    Get the color histogram within a specific portion of the bounding box in the HSV color space.
    """
    roi = adjust_bbox(image, bbox)
    # Converting to LAB color space
    roi_lab = cv2.cvtColor(roi, cv2.COLOR_BGR2Lab)
    roi_lab_filtered = filter_out_color_LAB(roi_lab, 127, 255)
    
    non_black_pixels = roi_lab_filtered[roi_lab_filtered.any(axis=-1)]
    color_counter = Counter(map(tuple, non_black_pixels))
    most_common_color = color_counter.most_common(1)[0][0]
        
    non_zero_subarrays = roi_lab_filtered[roi_lab_filtered.any(axis=-1)]
    
    hist = cv2.calcHist([roi_lab], [0, 1], None, [8, 8], [0, 180, 0, 256])
    
    
    cv2.normalize(hist, hist)
    """
    # Displaying the images
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 3, 1)
    plt.imshow(cv2.cvtColor(roi_lab, cv2.COLOR_Lab2RGB))
    plt.title("Filtered LAB")
    
    plt.subplot(1, 3, 2)
    plt.imshow(cv2.cvtColor(roi_lab_filtered, cv2.COLOR_Lab2RGB))
    plt.title("Filtered LAB")
    
    plt.subplot(1, 3, 3)
    plt.imshow([[most_common_color]])
    plt.title("Most Common Color")
    plt.axis('off')
    
    plt.show()
    """
    return hist.flatten()

def get_mean_color(image, bbox):
    """
    Get the mean color within a specific portion of the bounding box in both RGB and LAB color spaces,
    excluding green pixels.
    """
    roi = adjust_bbox(image, bbox)

    # Converting to LAB color space
    roi_lab = cv2.cvtColor(roi, cv2.COLOR_BGR2Lab)
    roi_lab_filtered = filter_out_color_LAB(roi_lab, 127, 255)
        
    non_zero_subarrays = roi_lab_filtered[roi_lab_filtered.any(axis=-1)]

    # Calculate the mean of each channel
    if non_zero_subarrays.size > 0:
        mean_color_lab = non_zero_subarrays.mean(axis=0)
        
        
    color_counter = Counter(map(tuple, non_zero_subarrays))
    most_common_color_lab = np.array(color_counter.most_common(1)[0][0], dtype=np.uint8)

    most_common_color_bgr = cv2.cvtColor(np.array([[most_common_color_lab]], dtype=np.uint8), cv2.COLOR_Lab2BGR)[0][0]
    mean_color_bgr = cv2.cvtColor(np.array([[mean_color_lab]], dtype=np.uint8), cv2.COLOR_Lab2BGR)[0][0]
    
    """
    # Displaying the images
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 3, 1)
    plt.imshow(cv2.cvtColor(roi_lab, cv2.COLOR_Lab2RGB))
    plt.title("Original LAB")

    plt.subplot(1, 3, 2)
    plt.imshow(cv2.cvtColor(roi_lab_filtered, cv2.COLOR_Lab2RGB))
    plt.title("Filtered LAB")
    
    plt.subplot(1, 3, 3)
    plt.imshow([[cv2.cvtColor(np.array([[mean_color_lab]], dtype=np.uint8), cv2.COLOR_Lab2RGB)[0][0]]])
    plt.title("Most Common Color")
    plt.axis('off')
    
    plt.show()
    """
    return most_common_color_lab, mean_color_lab

def perform_kmeans_clustering(colors, initial_centroids, color_multiplier=4, max_iter=10, n_clusters=2):
    """
    Perform k-means clustering on the given color data.
    """
    colors = np.array(colors)
    
    colors[:,1:3] *= 4
    if len(initial_centroids) != 0:
        kmeans = KMeans(n_clusters=2, init=initial_centroids, random_state=0, n_init=1, max_iter=max_iter).fit(colors)
    else:
        kmeans = KMeans(n_clusters=2, random_state=0).fit(colors)
        initial_centroids = kmeans.cluster_centers_
        
    # Reassign labels based on the order of centroids
    sorted_idx = np.argsort(initial_centroids[:, 0])  # Assuming the 0th feature is a color channel like Red
    mapping = np.zeros(n_clusters, dtype=int)
    for i, idx in enumerate(sorted_idx):
        mapping[idx] = i

    consistent_labels = mapping[kmeans.labels_]
    
    return consistent_labels, initial_centroids

# %%
from scipy.spatial import distance
from scipy import stats
    
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection



def plot_filtered_boxes(frame, boxes):
    plt.figure(figsize=(12, len(boxes) * 4))
    
    for i, box in enumerate(boxes):
        # Apply the ROI adjustment and color filtering
        roi = adjust_bbox(frame, box)
        roi_lab = cv2.cvtColor(roi, cv2.COLOR_BGR2Lab)
        roi_lab_filtered = filter_out_color_LAB(roi_lab, 127, 255)
        non_zero_colors = roi_lab_filtered[roi_lab_filtered.any(axis=-1)]

        plt.subplot(len(boxes), 2, i * 2 + 1)
        plt.imshow(cv2.cvtColor(roi, cv2.COLOR_BGR2RGB))
        plt.title(f"Original Box {i+1}")

        plt.subplot(len(boxes), 2, i * 2 + 2)
        plt.imshow(cv2.cvtColor(roi_lab_filtered, cv2.COLOR_Lab2RGB))
        plt.title(f"Filtered Box {i+1}")
        
    plt.show()

def compute_common_color_cluster_and_range(frame, boxes, num_clusters=2, delta=10):
    colors = []
    for box in boxes:
        roi = adjust_bbox(frame, box)
        roi_lab = cv2.cvtColor(roi, cv2.COLOR_BGR2Lab)
        roi_lab_filtered = filter_out_color_LAB(roi_lab, 127, 255)
        non_zero_colors = roi_lab_filtered[roi_lab_filtered.any(axis=-1)]
        colors.extend(non_zero_colors)

    if len(colors) == 0:
        print("All colors are filtered out.")
        return None, None

    # Applying K-means clustering to group colors
    kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(colors)
    cluster_centers = kmeans.cluster_centers_.astype(int)

    # Getting the most common cluster center (centroid)
    labels, counts = np.unique(kmeans.labels_, return_counts=True)
    most_common_cluster = cluster_centers[labels[np.argmax(counts)]]

    # Compute the color range
    lower_bound = np.clip(most_common_cluster - delta, 0, 255)
    upper_bound = np.clip(most_common_cluster + delta, 0, 255)

    # Plotting the most common color cluster center
    plt.figure(figsize=(6, 2))
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(most_common_cluster[np.newaxis, np.newaxis, :].astype(np.uint8), cv2.COLOR_Lab2RGB))
    plt.title("Most Common Cluster Center")
    plt.axis('off')

    # Plotting colors within the range
    plt.subplot(1, 2, 2)
    for i in range(5):
        sample_color = np.random.randint(lower_bound, upper_bound+1)
        plt.imshow(cv2.cvtColor(sample_color[np.newaxis, np.newaxis, :].astype(np.uint8), cv2.COLOR_Lab2RGB))
        plt.title("Colors Within Range")
        plt.axis('off')

    plt.show()

    return lower_bound, upper_bound    
    
def compute_common_color_and_range(frame, boxes, delta=10):
    colors = []
    for box in boxes:
        roi = adjust_bbox(frame, box)
        roi_lab = cv2.cvtColor(roi, cv2.COLOR_BGR2Lab)
        roi_lab_filtered = filter_out_color_LAB(roi_lab, 127, 255)
        non_zero_colors = roi_lab_filtered[roi_lab_filtered.any(axis=-1)]
        colors.extend(non_zero_colors)

    if len(colors) == 0:
        print("All colors are filtered out.")
        return None, None

    color_counter = Counter(map(tuple, colors))
    most_common_color = np.array(color_counter.most_common(1)[0][0], dtype=np.uint8)

    # Compute the color range
    lower_bound = most_common_color - delta
    upper_bound = most_common_color + delta
    
    # Ensure the bounds are valid
    if np.any(upper_bound < lower_bound):
        print("Invalid color range corrected.")
        lower_bound = most_common_color
        upper_bound = most_common_color
    
    lower_bound = np.clip(lower_bound, 0, 255)
    upper_bound = np.clip(upper_bound, 0, 255)

    # Plotting the most common color
    plt.figure(figsize=(6, 2))
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(most_common_color[np.newaxis, np.newaxis, :].astype(np.uint8), cv2.COLOR_Lab2RGB))
    plt.title("Most Common Color")
    plt.axis('off')
    
    plt.subplot(1, 2, 2)
    for i in range(5):
        sample_color = np.random.randint(lower_bound, upper_bound + 1, size=(1,1,3))
        plt.imshow(cv2.cvtColor(sample_color.astype(np.uint8), cv2.COLOR_Lab2RGB))
        plt.axis('off')

    return lower_bound, upper_bound


def nearest_points(centroids, data_points, n):
    # Calculate the distances between each data point and each centroid
    distances = distance.cdist(data_points, centroids, 'euclidean')
    
    # Get the n smallest distances' indices for each centroid
    nearest_indices = np.argsort(distances, axis=0)[:n]
    
    # Creating a dictionary to hold the indices of the nearest points for each centroid
    nearest_per_centroid = {i: nearest_indices[:, i].tolist() for i in range(centroids.shape[0])}

    return nearest_per_centroid


def compute_jersey_colors(first_frame, dets, bounding_boxes, classes, color_multiplier=4):
    # get_mean_color returns a tuple, 0 is most common color, 1 is mean color
    class_1_boxes = [bounding_box for bounding_box, cls in zip(bounding_boxes, classes) if cls == 1]
    colors_bounding_boxes = [(get_mean_color(first_frame, bounding_box)[1], bounding_box) for bounding_box in class_1_boxes]
    
    mean_colors = []
    for color_bbox in colors_bounding_boxes:
        mean_colors.append(color_bbox[0])
    
    initial_centroids = []
    mean_colors = np.array(mean_colors)
    label_clusters, centroids = perform_kmeans_clustering(mean_colors, initial_centroids, color_multiplier=color_multiplier)
    clustered_points = mean_colors.copy()
    clustered_points[:,1:3] *= color_multiplier
    
    close_points = nearest_points(centroids, clustered_points, 4)
    
    centroid_1_boxes = [class_1_boxes[i] for i in close_points[0]]
    centroid_2_boxes = [class_1_boxes[i] for i in close_points[1]]
    
    
    #plot_filtered_boxes(first_frame, centroid_1_boxes)
    #plot_filtered_boxes(first_frame, centroid_2_boxes)
    print("first")
    home1 = compute_common_color_cluster_and_range(first_frame, centroid_1_boxes)
    home = compute_common_color_and_range(first_frame, centroid_1_boxes)

    print("second")
    away1 = compute_common_color_cluster_and_range(first_frame, centroid_2_boxes)
    away = compute_common_color_and_range(first_frame, centroid_2_boxes)


    print("Most Dominant Color (in LAB):", away1)
    return (home, away)
    

def plot_lab_region(lower_bound, upper_bound):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    # Define the vertices of the region
    # Each vertex is a combination of the lower and upper values for L, a, and b
    vertices = [
        [lower_bound[0], lower_bound[1], lower_bound[2]],
        [upper_bound[0], lower_bound[1], lower_bound[2]],
        [upper_bound[0], upper_bound[1], lower_bound[2]],
        [lower_bound[0], upper_bound[1], lower_bound[2]],
        [lower_bound[0], lower_bound[1], upper_bound[2]],
        [upper_bound[0], lower_bound[1], upper_bound[2]],
        [upper_bound[0], upper_bound[1], upper_bound[2]],
        [lower_bound[0], upper_bound[1], upper_bound[2]]
    ]
    
    vertices = np.array(vertices)
    
    # Define the vertices that compose each of the 6 faces of the region
    faces = [
        [vertices[0], vertices[1], vertices[2], vertices[3]],
        [vertices[4], vertices[5], vertices[6], vertices[7]], 
        [vertices[0], vertices[1], vertices[5], vertices[4]], 
        [vertices[1], vertices[2], vertices[6], vertices[5]],
        [vertices[2], vertices[3], vertices[7], vertices[6]],
        [vertices[3], vertices[0], vertices[4], vertices[7]]
    ]
    
    # Draw the faces
    ax.add_collection3d(Poly3DCollection(faces, facecolors='cyan', linewidths=1, edgecolors='black', alpha=.25))
    
    ax.set_xlabel('L*')
    ax.set_ylabel('a*')
    ax.set_zlabel('b*')
    ax.set_xlim([0, 255])
    ax.set_ylim([-255, 255])
    ax.set_zlim([-255, 255])
    plt.show()

        
def get_team_belonging(image, bounding_box, home_color, away_color, should_plot=False):
    #blur_kernel_size = (2,2)
    #image = cv2.blur(image, blur_kernel_size)
    roi = adjust_bbox(image, bounding_box)
    
    # Converting to LAB color space
    roi_lab = cv2.cvtColor(roi, cv2.COLOR_BGR2LAB)
    
    roi_lab_away = roi_lab.copy()
    roi_lab_referee = roi_lab.copy()
    
    lower_blue = np.array([100, 50, 50])
    upper_blue = np.array([140, 255, 255])
    
    lower_white = np.array([0, 0, 200])
    upper_white = np.array([180, 50, 255])
    
    
    mask_home = cv2.inRange(roi_lab, home_color[0], home_color[1])
    #mask_home = cv2.inRange(roi_lab, lower_blue, upper_blue)
    result_home = cv2.bitwise_and(roi_lab, roi_lab, mask=mask_home)
    count_home = cv2.countNonZero(mask_home)
    
    mask_away = cv2.inRange(roi_lab_away, away_color[0], away_color[1])
    #mask_away = cv2.inRange(roi_lab_away, lower_white, upper_white)
    result_away = cv2.bitwise_and(roi_lab_away, roi_lab_away, mask=mask_away)
    count_away = cv2.countNonZero(mask_away)
    
    if should_plot:
        plt.figure(figsize=(10, 5))
        # Displaying the mask
        plt.subplot(1, 5, 1)
        plt.imshow(cv2.cvtColor(roi, cv2.COLOR_BGR2RGB))
        plt.title("Result")

        plt.subplot(1, 5, 2)
        plt.imshow(mask_home, cmap='gray')
        plt.title("Mask Home")

        # Displaying the result
        plt.subplot(1, 5, 3)
        plt.imshow(cv2.cvtColor(result_home, cv2.COLOR_HSV2RGB))
        plt.title("Result Home")

        plt.subplot(1, 5, 4)
        plt.imshow(mask_away, cmap='gray')
        plt.title("Mask Away")

        # Displaying the result
        plt.subplot(1, 5, 5)
        plt.imshow(cv2.cvtColor(result_away, cv2.COLOR_HSV2RGB))
        plt.title("Result Away")

        plt.show()
        
        
    team = -1
    
    if count_away > count_home:
        team = 1
        print("Away team")
    else:
        print("Home team")
        team = 0
        
    return team

# %%
def process_video(input_file, output_file, tracker, yolov8, do_kmeans, conf=0.3):
    """
    Process the input video, perform object detection and tracking, and save the results to the output video.
    """
    input_video = cv2.VideoCapture(input_file)
    width = int(input_video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(input_video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = input_video.get(cv2.CAP_PROP_FPS)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_file, fourcc, fps, (width, height))
    
    thickness = 2
    fontscale = 0.5
    
    # Function to get unique colors for each class id
    def get_color(cls_id):
        np.random.seed(cls_id)
        return tuple(np.random.randint(0, 255, 3).tolist())
    
   

    initial_centroids = []
    counter = 1
    while True:
        print(counter)
        ret, image = input_video.read()
        if not ret:
            break
        
        predicted = yolov8.predict(image, conf=conf)
        detections = predicted[0].boxes.data.cpu().numpy()
        
        dets = []
        ball = np.array([])
        highest_conf = 0
        
        
        for bounding_boxes in detections:
            if bounding_boxes[-1:] != 0:
                dets.append(bounding_boxes)
            if bounding_boxes[5] == 0:
                if bounding_boxes[4] > highest_conf:
                    highest_conf = bounding_boxes[4]
                    ball = bounding_boxes
                
                
        dets = np.array(dets)
        
        tracks = tracker.update(dets, image)
        
        # Set im = image so we can do transforms on the image for better color identification
        # Without altering the original image so when writing the video it looks the same
        #im = cv2.addWeighted(image, 0.75, image, 0.5, 0)
        im = image
        
        if tracks.size > 0:  # Check if tracks is not empty
            xyxys = tracks[:, 0:4].astype('int')
            ids = tracks[:, 4].astype('int')
            clss = tracks[:, 6].astype('int')
        else:
            print("Tracks is empty or not in expected format.")

        if(counter == 1):
            home, away = compute_jersey_colors(im, dets, xyxys, clss)
            
           # plot_lab_region(home[0], home[1])
            plot_lab_region(away[0], away[1])
            
            plt.figure(figsize=(10, 5))
    
            # Displaying the mask
            plt.subplot(1, 4, 1)
             # Plotting the most common color
            plt.imshow(cv2.cvtColor(home[0][np.newaxis, np.newaxis, :].astype(np.uint8), cv2.COLOR_Lab2RGB))
            plt.title("Home Lower")
            
            plt.subplot(1, 4, 2)
            plt.imshow(cv2.cvtColor(home[1][np.newaxis, np.newaxis, :].astype(np.uint8), cv2.COLOR_Lab2RGB))
            plt.title("Home Upper")
            
            plt.subplot(1, 4, 3)
            plt.imshow(cv2.cvtColor(away[0][np.newaxis, np.newaxis, :].astype(np.uint8), cv2.COLOR_Lab2RGB))
            plt.title("Away Lower")
            
            plt.subplot(1, 4, 4)
            plt.imshow(cv2.cvtColor(away[1][np.newaxis, np.newaxis, :].astype(np.uint8), cv2.COLOR_Lab2RGB))
            plt.title("Away Upper")
            
            plt.show()
            
        if tracks.shape[0] != 0:
            player_mean_colors = [get_mean_color(im, xyxy)[1] for xyxy, cls in zip(xyxys, clss) if cls == 1]
            #player_mean_colors = [get_color_histogram(im, xyxy) for xyxy, cls in zip(xyxys, clss) if cls == 1]
            
            if(len(initial_centroids) == 0):
                labels, initial_centroids = perform_kmeans_clustering(player_mean_colors, initial_centroids)

            else:
                if do_kmeans:
                    labels = perform_kmeans_clustering(player_mean_colors, initial_centroids)[0]
                else:
                    labels = [get_team_belonging(im, xyxy, home, away) for xyxy, cls in zip(xyxys, clss) if cls == 1]
                
                """
                player_mean_colors = np.array([lab_to_rgb(color) for color in player_mean_colors])
                
                # Plotting the results (optional)
                plt.subplot(1, 2, 1)
                plt.scatter(player_mean_colors[:, 1], player_mean_colors[:, 2], c=player_mean_colors / 255.0)
                plt.title('Original Colors')

                plt.subplot(1, 2, 2)
                plt.scatter(player_mean_colors[labels == 0][:, 1], player_mean_colors[labels == 0][:, 2], c='blue', marker='o')
                plt.scatter(player_mean_colors[labels == 1][:, 1], player_mean_colors[labels == 1][:, 2], c='red', marker='x')
                plt.title('Clustered Colors')

                plt.show()
                """    
    
            for xyxy, id, cls, label in zip(xyxys, ids, clss, labels):
                
                
                # Convert bounding box coordinates to Rect object
                rect = Rect(xyxy[0], xyxy[1], xyxy[2], xyxy[3])
                if cls == 1:
                    cls = cls + label
                
                # Get a unique color for each class
                color = Color(*get_color(cls))

                # Draw an ellipse at the bottom of the bounding box
                draw_ellipse(image, rect, color, thickness)
                
                # Place ID text just above the ellipse
                cv2.putText(
                    image,
                    f'{id}',
                    (rect.bottom_center[0] - 10, rect.bottom_center[1] - int(0.35 * rect.width) - 5),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    fontscale,
                    color.bgr_tuple,
                    thickness
                )
            if len(ball) != 0:
                rect = Rect(int(ball[0]), int(ball[1]), int(ball[2]), int(ball[3]))
                # Get a unique color for each class
                color = Color(*get_color(0))

                # Draw an ellipse at the bottom of the bounding box
                draw_ellipse(image, rect, color, thickness)
                id = -1
                # Place ID text just above the ellipse
                cv2.putText(
                    image,
                    "-1",
                    (rect.bottom_center[0] - 10, rect.bottom_center[1] - int(0.35 * rect.width) - 5),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    fontscale,
                    color.bgr_tuple,
                    thickness
                )
            
                
        out.write(image)
        counter += 1
        
    input_video.release()
    out.release()
    cv2.destroyAllWindows()

# %%
from pathlib import Path
import warnings
import time

warnings.filterwarnings("ignore")
model_weights = Path('osnet_x1_0_market1501.pt')
yolo_model_path = 'runs/detect/New_data_600_V/weights/best.pt'
input_video_file = "videos/2sec.mp4"
output_video_name = create_new_file(input_video_file.split(".")[0] + "_tracking_output_test.mp4")

print("Tracking output: " + output_video_name)
output_video_file = output_video_name

home_team_color="white"
away_team_color="blue"

tracker = initialize_tracker(model_weights)
yolov8 = initialize_yolo(yolo_model_path)


start_time = time.time()
process_video(input_video_file, output_video_file, tracker, yolov8, True)
end_time = time.time()

execution_time = end_time - start_time

print(f"Time taken to process video: {execution_time} seconds")
# Out:
# 2023-10-23 14:58:19.525 | SUCCESS  | boxmot.appearance.reid_model_factory:load_pretrained_weights:207 - Successfully loaded pretrained weights from "osnet_x1_0_market1501.pt"
# Tracking output: videos/2sec_tracking_output_test.mp4
# 1
# 0: 1120x1984 1 ball, 22 players, 63.9ms
# Speed: 12.7ms preprocess, 63.9ms inference, 1.2ms postprocess per image at shape (1, 3, 1120, 1984)
# first
# second
# Invalid color range corrected.
# Most Dominant Color (in LAB): (array([218, 115, 122]), array([238, 135, 142]))
# 0: 1120x1984 1 ball, 23 players, 61.6ms
# Speed: 11.7ms preprocess, 61.6ms inference, 1.4ms postprocess per image at shape (1, 3, 1120, 1984)
6ms inference, 1.3ms postprocess per image at shape (1, 3, 1120, 1984)
#
# 0: 1120x1984 2 balls, 22 players, 61.5ms
# Speed: 12.6ms preprocess, 61.5ms inference, 1.2ms postprocess per image at shape (1, 3, 1120, 1984)
# 42
# 43
# 0: 1120x1984 2 balls, 22 players, 61.6ms
# Speed: 14.6ms preprocess, 61.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1120, 1984)
#
# 0: 1120x1984 1 ball, 22 players, 61.6ms
# Speed: 11.8ms preprocess, 61.6ms inference, 1.4ms postprocess per image at shape (1, 3, 1120, 1984)
# 44
# 45
# 0: 1120x1984 1 ball, 22 players, 63.8ms
# Speed: 11.6ms preprocess, 63.8ms inference, 1.3ms postprocess per image at shape (1, 3, 1120, 1984)
#
# 0: 1120x1984 1 ball, 22 players, 61.7ms
# Speed: 11.8ms preprocess, 61.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1120, 1984)
# 46
# 47
# 0: 1120x1984 1 ball, 23 players, 63.0ms
# Speed: 11.8ms preprocess, 63.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1120, 1984)
#
# 0: 1120x1984 1 ball, 23 players, 61.6ms
# Speed: 11.9ms preprocess, 61.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1120, 1984)
# 48
# 49
# 0: 1120x1984 1 ball, 23 players, 63.1ms
# Speed: 11.9ms preprocess, 63.1ms inference, 1.3ms postprocess per image at shape (1, 3, 1120, 1984)
#
# 0: 1120x1984 1 ball, 23 players, 62.2ms
# Speed: 11.7ms preprocess, 62.2ms inference, 1.3ms postprocess per image at shape (1, 3, 1120, 1984)
# 50
# 51
# 0: 1120x1984 1 ball, 23 players, 63.2ms
# Speed: 11.6ms preprocess, 63.2ms inference, 1.3ms postprocess per image at shape (1, 3, 1120, 1984)
#
# 0: 1120x1984 1 ball, 23 players, 61.6ms
# Speed: 11.9ms preprocess, 61.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1120, 1984)
# 52
# 53
# 0: 1120x1984 1 ball, 23 players, 63.2ms
# Speed: 11.9ms preprocess, 63.2ms inference, 1.3ms postprocess per image at shape (1, 3, 1120, 1984)
#
# 0: 1120x1984 1 ball, 23 players, 62.0ms
# Speed: 11.9ms preprocess, 62.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1120, 1984)
# 54
# 55
# 0: 1120x1984 1 ball, 23 players, 61.7ms
# Speed: 12.5ms preprocess, 61.7ms inference, 1.2ms postprocess per image at shape (1, 3, 1120, 1984)
#
# 0: 1120x1984 1 ball, 23 players, 61.7ms
# Speed: 12.3ms preprocess, 61.7ms inference, 1.2ms postprocess per image at shape (1, 3, 1120, 1984)
# 56
# 57
# 0: 1120x1984 2 balls, 23 players, 63.0ms
# Speed: 11.7ms preprocess, 63.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1120, 1984)
#
# 0: 1120x1984 1 ball, 23 players, 61.7ms
# Speed: 12.2ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1120, 1984)
# 58
# 59
# 0: 1120x1984 1 ball, 23 players, 63.1ms
# Speed: 12.2ms preprocess, 63.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1120, 1984)
#
# 0: 1120x1984 1 ball, 23 players, 62.2ms
# Speed: 12.2ms preprocess, 62.2ms inference, 1.4ms postprocess per image at shape (1, 3, 1120, 1984)
# 60
# 61
# Time taken to process video: 11.25059199333191 seconds

# %%
import matplotlib.pyplot as plt
import json
import os

# Load the JSON data
filename = "Calibration_Keypoint/00000.json"
with open(filename, 'r') as f:
    data = json.load(f)

# Load the image
img = plt.imread(filename.replace(".json", ".jpg"))  # assuming it's a .jpg, adjust as needed
plt.imshow(img)

# Plot each set of points
for key, points in data.items():
    # Extract x and y coordinates
    x = [point['x'] for point in points]
    y = [point['y'] for point in points]
    
    # Scale the coordinates to the image dimensions
    h, w, _ = img.shape
    x = [i * w for i in x]
    y = [j * h for j in y]
    
    # Draw the shape
    plt.plot(x, y, label=key, marker='o')

plt.axis('off')  # to hide axes

# Display or save the image
plt.show()
#plt.savefig(os.path.splitext(filename)[0] + "_output.jpg", bbox_inches='tight', pad_inches=0)

# %%
import json
import os

# Path to the folder containing JSON files
folder_path = "field_keypoints"
output_folder = "field_training/labels"

# Function to convert data to YOLO format
def convert_to_yolo_format(label, coords):
    x_center = (coords[0]['x'] + coords[1]['x']) / 2.0
    y_center = (coords[0]['y'] + coords[1]['y']) / 2.0
    width = abs(coords[1]['x'] - coords[0]['x'])
    height = abs(coords[1]['y'] - coords[0]['y'])
    return f"{label} {x_center} {y_center} {width} {height}"

# Iterate over each JSON file in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith(".json"):
        with open(os.path.join(folder_path, file_name), "r") as f:
            data = json.load(f)
        
        labels = {name: idx for idx, name in enumerate(data.keys())}
        
        yolo_data = []
        for name, coords_list in data.items():
            if len(coords_list) >= 2:
                yolo_data.append(convert_to_yolo_format(labels[name], coords_list))
        
        # Create a corresponding output file for each JSON file
        output_file_name = os.path.splitext(file_name)[0] + ".txt"
        with open(os.path.join(output_folder, output_file_name), "w") as f:
            for line in yolo_data:
                f.write(line + "\n")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3245453/1590631053.py in <module>
#      25         for name, coords_list in data.items():
#      26             if len(coords_list) >= 2:
# ---> 27                 yolo_data.append(convert_to_yolo_format(labels[name], coords_list))
#      28
#      29         # Create a corresponding output file for each JSON file
#
# /tmp/ipykernel_3245453/1590631053.py in convert_to_yolo_format(label, coords)
#       8 # Function to convert data to YOLO format
#       9 def convert_to_yolo_format(label, coords):
# ---> 10     x_center = (coords[0]['x'] + coords[1]['x']) / 2.0
#      11     y_center = (coords[0]['y'] + coords[1]['y']) / 2.0
#      12     width = abs(coords[1]['x'] - coords[0]['x'])
#
# KeyError: 0

# %%
import json
import os

# Path to the folder containing JSON files
folder_path = "field_keypoints"
output_folder = "field_training/labels"

# Function to convert data to YOLO format
def convert_to_yolo_format(label, coords):
    if not all(isinstance(coord, dict) for coord in coords):
        print(f"Unexpected data format. Expected a list of dictionaries but got {coords}")
        return None

    if not all('x' in coord and 'y' in coord for coord in coords):
        print(f"Expected dictionaries with 'x' and 'y' keys but got {coords}")
        return None

    x_center = (coords[0]['x'] + coords[1]['x']) / 2.0
    y_center = (coords[0]['y'] + coords[1]['y']) / 2.0
    width = abs(coords[1]['x'] - coords[0]['x'])
    height = abs(coords[1]['y'] - coords[0]['y'])
    return f"{label} {x_center} {y_center} {width} {height}"

# Iterate over each JSON file in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith(".json"):
        with open(os.path.join(folder_path, file_name), "r") as f:
            data = json.load(f)
        
        labels = {name: idx for idx, name in enumerate(data.keys())}
        
        yolo_data = []
        for name, coords_list in data.items():
            if len(coords_list) >= 2:
                converted_data = convert_to_yolo_format(labels[name], coords_list)
                if converted_data:
                    yolo_data.append(converted_data)
        
        # Create a corresponding output file for each JSON file
        output_file_name = os.path.splitext(file_name)[0] + "_output.txt"
        with open(os.path.join(output_folder, output_file_name), "w") as f:
            for line in yolo_data:
                f.write(line + "\n")
# Out:
# Unexpected data format. Expected a list of dictionaries but got {'00000.jpg': {'ms_time': 271751, 'replay_time': 271751, 'event_id': '0', 'half': 1}, '00001.jpg': {'ms_time': 271751, 'replay_time': 285052, 'event_id': '0', 'half': 1}, '00002.jpg': {'ms_time': 790722, 'replay_time': 790722, 'event_id': '1', 'half': 1}, '00003.jpg': {'ms_time': 790722, 'replay_time': 2267716, 'event_id': '1', 'half': 1}, '00004.jpg': {'ms_time': 790722, 'replay_time': 829929, 'event_id': '1', 'half': 1}, '00005.jpg': {'ms_time': 790722, 'replay_time': 836885, 'event_id': '1', 'half': 1}, '00006.jpg': {'ms_time': 790722, 'replay_time': 2265
_id': '19', 'half': 2}, '16447.jpg': {'ms_time': 1201316, 'replay_time': 1201316, 'event_id': '20', 'half': 2}, '16448.jpg': {'ms_time': 1201316, 'replay_time': 1221253, 'event_id': '20', 'half': 2}, '16449.jpg': {'ms_time': 1522592, 'replay_time': 1522592, 'event_id': '21', 'half': 2}, '16450.jpg': {'ms_time': 1522592, 'replay_time': 1539599, 'event_id': '21', 'half': 2}, '16451.jpg': {'ms_time': 1634867, 'replay_time': ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import os
os.listdir("field_training/labels")
# Out:
# ['01407_output.txt',
#  '09103_output.txt',
#  '09742_output.txt',
#  '14590_output.txt',
#  '07849_output.txt',
#  '14190_output.txt',
#  '06833_output.txt',
#  '00682_output.txt',
#  '05492.txt',
#  '00843_output.txt',
#  '00696_output.txt',
#  '01052_output.txt',
#  '11763_output.txt',
#  '00743_output.txt',
#  '05978_output.txt',
#  '04714_output.txt',
#  '15345_output.txt',
#  '12840_output.txt',
#  '03649_output.txt',
#  '05248_output.txt',
#  '01220_output.txt',
#  '08264_output.txt',
#  '04203_output.txt',
#  '00308_output.txt',
#  '02109_output.txt',
#  '11949_output.txt',
#  '06389_output.txt',
#  '03844_output.txt',
#  '14525_output.txt',
#  '07655_output.txt',
#  '03865_output.txt',
#  '15421_output.txt',
#  '01377_output.txt',
#  '08805_output.txt',
#  '13043_output.txt',
#  '10682_output.txt',
#  '10904_output.txt',
#  '00444_output.txt',
#  '15544_output.txt',
#  '14974_output.txt',
#  '06459_output.txt',
#  '08538_output.txt',
#  '14928_output.txt',
#  '14280_output.txt',
#  '06057_output.txt',
#  '15614_output.txt',
#  '02767_output.txt',
#  '00803_output.txt',
#  '11457_output.txt',
#  '15060_output.txt',
#  '11467_output.txt',
#  '14569_output.txt',
#  '00659_output.txt',
#  '01417_output.txt',
#  '02926_output.txt',
#  '08505_output.txt',
#  '13827_output.txt',
#  '15444_output.txt',
#  '08578_output.txt',
#  '12534_output.txt',
#  '11424_output.txt',
#  '11740_output.txt',
#  '04474.txt',
#  '00840_output.txt',
#  '16254_output.txt',
#  '13678_output.txt',
#  '16420_output.txt',
#  '09671_output.txt',
#  '15438_output.txt',
#  '09854_output.txt',
#  '11096_output.txt',
#  '03019_output.txt',
#  '00003_output.txt',
#  '00941_output.txt',
#  '07949_output.txt',
#  '10169_output.txt',
#  '05365_output.txt',
#  '05334_output.txt',
#  '05305_output.txt',
#  '12265_output.txt',
#  '10908_output.txt',
#  '04963_output.txt',
#  '13559_output.txt',
#  '12686_output.txt',
#  '07442_output.txt',
#  '12360_output.txt',
#  '07288_output.txt',
#  '15620_output.txt',
#  '09660_output.txt',
#  '09708_output.txt',
#  '15193_output.txt',
#  '09812_output.txt',
#  '00309_output.txt',
#  '11137_output.txt',
#  '16217_output.txt',
#  '03213_output.txt',
#  '03728_output.txt',
#  '07390_output.txt',
#  '10810_output.txt',
#  '14778_output.txt',
#  '09038_output.txt',
#  '15034_output.txt',
#  '12425_output.txt',
#  '02406_output.txt',
#  '09153_output.txt',
#  '07272_output.txt',
#  '16129_output.txt',
#  '06636_output.txt',
#  '03942_output.txt',
#  '03382_output.txt',
#  '09353_output.txt',
#  '10392_output.txt',
#  '00961_output.txt',
#  '02675_output.txt',
#  '12781_output.txt',
#  '11741_output.txt',
#  '12845.txt',
#  '13014_output.txt',
#  '05118_output.txt',
#  '05175_output.txt',
#  '06059_output.txt',
#  '05881_output.txt',
#  '00331_output.txt',
#  '02354_output.txt',
#  '02468_output.txt',
#  '16211_output.txt',
#  '08228_output.txt',
#  '04590_output.txt',
#  '10211_output.txt',
#  '02397_output.txt',
#  '13077_output.txt',
#  '02720_output.txt',
#  '08250_output.txt',
#  '16392_output.txt',
#  '07777_output.txt',
#  '08379_output.txt',
#  '07001_output.txt',
#  '04537_output.txt',
#  '12783_output.txt',
#  '01225_output.txt',
#  '13440_output.txt',
#  '00714_output.txt',
#  '04296_output.txt',
#  '04366_output.txt',
#  '00165_output.txt',
#  '14185_output.txt',
#  '00118_output.txt',
#  '12512_output.txt',
#  '11168_output.txt',
#  '01352_output.txt',
#  '04992_output.txt',
#  '06667_output.txt',
#  '00134_output.txt',
#  '10969_output.txt',
#  '06269_output.txt',
#  '05203_output.txt',
#  '11976_output.txt',
#  '10658_output.txt',
#  '07554_output.txt',
#  '13015_output.txt',
#  '00931_output.txt',
#  '10872_output.txt',
#  '05381_output.txt',
#  '03973_output.txt',
#  '10690_output.txt',
#  '16021_output.txt',
#  '10775_output.txt',
#  '00051_output.txt',
#  '03982_output.txt',
#  '02088_output.txt',
#  '03573_output.txt',
#  '06462_output.txt',
#  '15240_output.txt',
#  '13467_output.txt',
#  '16090_output.txt',
#  '02412_output.txt',
#  '04271_output.txt',
#  '12112_output.txt',
#  '15834_output.txt',
#  '15586_output.txt',
#  '09550_output.txt',
#  '01983_output.txt',
#  '03247_output.txt',
#  '06654_output.txt',
#  '09142_output.txt',
#  '14240_output.txt',
#  '12963_output.txt',
#  '07708_output.txt',
#  '05004_output.txt',
#  '02533_output.txt',
#  '02903_output.txt',
#  '14459_output.txt',
#  '08076_output.txt',
#  '09508_output.txt',
#  '08057_output.txt',
#  '13764_output.txt',
#  '06005_output.txt',
#  '03150_output.txt',
#  '10763_output.txt',
#  '07846_output.txt',
#  '02168_output.txt',
#  '16290_output.txt',
#  '03201_output.txt',
#  '01105_output.txt',
#  '01697_output.txt',
#  '07996_output.txt',
#  '06738_output.txt',
#  '09429_output.txt',
#  '09432_output.txt',
#  '01229_output.txt',
#  '10915_output.txt',
#  '06257_output.txt',
#  '03871_output.txt',
#  '01969_output.txt',
#  '10215_output.txt',
#  '04907_output.txt',
#  '12167_output.txt',
#  '15142_output.txt',
#  '12928_output.txt',
#  '14858_output.txt',
#  '07400_output.txt',
#  '12462_output.txt',
#  '05430_output.txt',
#  '10667_output.txt',
#  '15137_output.txt',
#  '05492_output.txt',
#  '06173_output.txt',
#  '06147_output.txt',
#  '12910_output.txt',
#  '02968_output.txt',
#  '03909_output.txt',
#  '11996_output.txt',
#  '03308_output.txt',
#  '05555_output.txt',
#  '09364_output.txt',
#  '14097_output.txt',
#  '16260_output.txt',
#  '02138_output.txt',
#  '12880_output.txt',
#  '07466_output.txt',
#  '01126_output.txt',
#  '08843_output.txt',
#  '15021_output.txt',
#  '00222_output.txt',
#  '06893_output.txt',
#  '11868_output.txt',
#  '13722_output.txt',
#  '14921_output.txt',
#  '02813_output.txt',
#  '01233_output.txt',
#  '01809_output.txt',
#  '16040_output.txt',
#  '13124_output.txt',
#  '07451_output.txt',
#  '16191_output.txt',
#  '04735_output.txt',
#  '06998_output.txt',
#  '04500_output.txt',
#  '03184_output.txt',
#  '00148_output.txt',
#  '02201_output.txt',
#  '03856_output.txt',
#  '14664_output.txt',
#  '04291_output.txt',
#  '07911_output.txt',
#  '13683_output.txt',
#  '09042_output.txt',
#  '00115_output.txt',
#  '03759_output.txt',
#  '08973_output.txt',
#  '02953_output.txt',
#  '13598_output.txt',
#  '14253_output.txt',
#  '01441_output.txt',
#  '16176_output.txt',
#  '15800_output.txt',
#  '03757_output.txt',
#  '14236_output.txt',
#  '09138_output.txt',
#  '00018_output.txt',
#  '10652_output.txt',
#  '10797.txt',
#  '03159_output.txt',
#  '10599_output.txt',
#  '00657_output.txt',
#  '11985_output.txt',
#  '15110_output.txt',
#  '00450_output.txt',
#  '02925_output.txt',
#  '10143_output.txt',
#  '08472_output.txt',
#  '14110_output.txt',
#  '08603_output.txt',
#  '13950_output.txt',
#  '13008_output.txt',
#  '06725_output.txt',
#  '00236_output.txt',
#  '15256_output.txt',
#  '13000_output.txt',
#  '15322_output.txt',
#  '16171_output.txt',
#  '05382_output.txt',
#  '04773_output.txt',
#  '06789_output.txt',
#  '02862_output.txt',
#  '10410_output.txt',
#  '01822_output.txt',
#  '09308_output.txt',
#  '05687_output.txt',
#  '05836_output.txt',
#  '14173_output.txt',
#  '11468_output.txt',
#  '01892_output.txt',
#  '11598_output.txt',
#  '11247_output.txt',
#  '08557_output.txt',
#  '10765_output.txt',
#  '04687.txt',
#  '10706_output.txt',
#  '13811_output.txt',
#  '06497_output.txt',
#  '10788_output.txt',
#  '13355_output.txt',
#  '04465_output.txt',
#  '11478_output.txt',
#  '04909_output.txt',
#  '05213_output.txt',
#  '04153_output.txt',
#  '10403_output.txt',
#  '04973_output.txt',
#  '01655_output.txt',
#  '14014_output.txt',
#  '03583_output.txt',
#  '15044_output.txt',
#  '10229_output.txt',
#  '13096.txt',
#  '16355_output.txt',
#  '11965_output.txt',
#  '09977_output.txt',
#  '11442_output.txt',
#  '14481_output.txt',
#  '12917_output.txt',
#  '02757_output.txt',
#  '10233_output.txt',
#  '16410_output.txt',
#  '10212_output.txt',
#  '05459_output.txt',
#  '15466_output.txt',
#  '02889_output.txt',
#  '12885_output.txt',
#  '06039_output.txt',
#  '03272_output.txt',
#  '16130_output.txt',
#  '05368_output.txt',
#  '07550_output.txt',
#  '04879_output.txt',
#  '09795_output.txt',
#  '00639_output.txt',
#  '00593_output.txt',
#  '03402_output.txt',
#  '12795_output.txt',
#  '13428_output.txt',
#  '08814_output.txt',
#  '11294_output.txt',
#  '14439_output.txt',
#  '16451_output.txt',
#  '15057_output.txt',
#  '02692_output.txt',
#  '03318_output.txt',
#  '12169_output.txt',
#  '07168_output.txt',
#  '06503_output.txt',
#  '10726_output.txt',
#  '07430_output.txt',
#  '00652_output.txt',
#  '11385_output.txt',
#  '10778_output.txt',
#  '12055_output.txt',
#  '08588_output.txt',
#  '10061_output.txt',
#  '05125_output.txt',
#  '05548_output.txt',
#  '09154_output.txt',
#  '02444_output.txt',
#  '10163_output.txt',
#  '07149_output.txt',
#  '02141_output.txt',
#  '05610_output.txt',
#  '03218_output.txt',
#  '06947_output.txt',
#  '03733_output.txt',
#  '08911_output.txt',
#  '00934_output.txt',
#  '12495_output.txt',
#  '00936_output.txt',
#  '16425_output.txt',
#  '06733_output.txt',
#  '04911_output.txt',
#  '15282_output.txt',
#  '15576_output.txt',
#  '09761_output.txt',
#  '07160_output.txt',
#  '12804_output.txt',
#  '15270_output.txt',
#  'match_info_output.txt',
#  '13536_output.txt',
#  '09696_output.txt',
#  '02190_output.txt',
#  '09190_output.txt',
#  '02870.txt',
#  '12173_output.txt',
#  '05617_output.txt',
#  '00874_output.txt',
#  '04951_output.txt',
#  '04878_output.txt',
#  '08011_output.txt',
#  '13910_output.txt',
#  '07979_output.txt',
#  '12513_output.txt',
#  '00675_output.txt',
#  '01416_output.txt',
#  '07193_output.txt',
#  '05950_output.txt',
#  '05871_output.txt',
#  '01289_output.txt',
#  '13778_output.txt',
#  '13404_output.txt',
#  '05452_output.txt',
#  '06935_output.txt',
#  '03840_output.txt',
#  '12174_output.txt',
#  '09808_output.txt',
#  '07387_output.txt',
#  '15315_output.txt',
#  '04686_output.txt',
#  '01432_output.txt',
#  '01124_output.txt',
#  '00369_output.txt',
#  '06132_output.txt',
#  '08413_output.txt',
#  '08309_output.txt',
#  '03569_output.txt',
#  '06355_output.txt',
#  '13073_output.txt',
#  '05984_output.txt',
#  '06943_output.txt',
#  '05428_output.txt',
#  '02329_output.txt',
#  '07154_output.txt',
#  '06618_output.txt',
#  '05641_output.txt',
#  '09167_output.txt',
#  '03428_output.txt',
#  '02310_output.txt',
#  '14427_output.txt',
#  '02753_output.txt',
#  '06043_output.txt',
#  '01723_output.txt',
#  '03678_output.txt',
#  '09915_output.txt',
#  '05833_output.txt',
#  '12453_output.txt',
#  '01959_output.txt',
#  '04306_output.txt',
#  '01337_output.txt',
#  '02493_output.txt',
#  '07843_output.txt',
#  '13832_output.txt',
#  '04317_output.txt',
#  '03513_output.txt',
#  '04884_output.txt',
#  '10426_output.txt',
#  '15372_output.txt',
#  '04791_output.txt',
#  '09225_output.txt',
#  '04201_output.txt',
#  '02002_output.txt',
#  '06593_output.txt',
#  '01167_output.txt',
#  '13249_output.txt',
#  '12273_output.txt',
#  '09704_output.txt',
#  '13905_output.txt',
#  '07897_output.txt',
#  '10718_output.txt',
#  '11308_output.txt',
#  '14003_output.txt',
#  '02550_output.txt',
#  '06516_output.txt',
#  '11019_output.txt',
#  '04930_output.txt',
#  '04724_output.txt',
#  '15685_output.txt',
#  '02840_output.txt',
#  '02869_output.txt',
#  '09532_output.txt',
#  '15623_output.txt',
#  '03031_output.txt',
#  '16458_output.txt',
#  '11669_output.txt',
#  '05085_output.txt',
#  '06001_output.txt',
#  '12109_output.txt',
#  '02970_output.txt',
#  '08037_output.txt',
#  '08622_output.txt',
#  '10210_output.txt',
#  '11445_output.txt',
#  '06256_output.txt',
#  '07940_output.txt',
#  '12809_output.txt',
#  '07774_output.txt',
#  '13169_output.txt',
#  '13813_output.txt',
#  '09531_output.txt',
#  '02547_output.txt',
#  '11644_output.txt',
#  '08206_output.txt',
#  '02106_output.txt',
#  '12440_output.txt',
#  '07468_output.txt',
#  '09261_output.txt',
#  '11832_output.txt',
#  '11212_output.txt',
#  '04341_output.txt',
#  '00083_output.txt',
#  '00667_output.txt',
#  '02900_output.txt',
#  '14629_output.txt',
#  '10731_output.txt',
#  '02259_output.txt',
#  '03153_output.txt',
#  '11920_output.txt',
#  '08428_output.txt',
#  '00321_output.txt',
#  '13239_output.txt',
#  '13943_output.txt',
#  '04830_output.txt',
#  '11322_output.txt',
#  '12978_output.txt',
#  '15548_output.txt',
#  '15111_output.txt',
#  '13164_output.txt',
#  '09268_output.txt',
#  '10967_output.txt',
#  '02487_output.txt',
#  '13336_output.txt',
#  '08166_output.txt',
#  '11183_output.txt',
#  '09488_output.txt',
#  '11803_output.txt',
#  '00643_output.txt',
#  '03309_output.txt',
#  '04077_output.txt',
#  '00522_output.txt',
#  '03510_output.txt',
#  '03765_output.txt',
#  '11431_output.txt',
#  '06647_output.txt',
#  '16388_output.txt',
#  '07673_output.txt',
#  '09214_output.txt',
#  '11434_output.txt',
#  '14466_output.txt',
#  '00686_output.txt',
#  '01145_output.txt',
#  '09351_output.txt',
#  '14299_output.txt',
#  '00726_output.txt',
#  '10871_output.txt',
#  '13431_output.txt',
#  '10668_output.txt',
#  '05856_output.txt',
#  '14869_output.txt',
#  '07315_output.txt',
#  '07960_output.txt',
#  '10562_output.txt',
#  '09459_output.txt',
#  '10634_output.txt',
#  '04630_output.txt',
#  '01707_output.txt',
#  '00882_output.txt',
#  '02713_output.txt',
#  '11758_output.txt',
#  '00979_output.txt',
#  '06245_output.txt',
#  '09598_output.txt',
#  '00723_output.txt',
#  '11079_output.txt',
#  '02591_output.txt',
#  '08628_output.txt',
#  '08282_output.txt',
#  '00544_output.txt',
#  '14516_output.txt',
#  '03858_output.txt',
#  '02098_output.txt',
#  '12043_output.txt',
#  '12178_output.txt',
#  '03913_output.txt',
#  '09402_output.txt',
#  '01420_output.txt',
#  '08573_output.txt',
#  '08322_output.txt',
#  '11069_output.txt',
#  '13268_output.txt',
#  '03993_output.txt',
#  '06565_output.txt',
#  '07378_output.txt',
#  '03291_output.txt',
#  '07715_output.txt',
#  '01080_output.txt',
#  '00119_output.txt',
#  '08465_output.txt',
#  '12974_output.txt',
#  '03894_output.txt',
#  '08728_output.txt',
#  '11406_output.txt',
#  '02267_output.txt',
#  '15602_output.txt',
#  '12535_output.txt',
#  '11684_output.txt',
#  '03469_output.txt',
#  '12466_output.txt',
#  '02461_output.txt',
#  '01751_output.txt',
#  '10373_output.txt',
#  '02659_output.txt',
#  '14041_output.txt',
#  '16064_output.txt',
#  '14142_output.txt',
#  '02858_output.txt',
#  '09943_output.txt',
#  '09469_output.txt',
#  '11527_output.txt',
#  '06049_output.txt',
#  '13816_output.txt',
#  '07062_output.txt',
#  '03065_output.txt',
#  '07621_output.txt',
#  '05396_output.txt',
#  '14495_output.txt',
#  '14286_output.txt',
#  '11488_output.txt',
#  '04248_output.txt',
#  '06642_output.txt',
#  '16301_output.txt',
#  '06105_output.txt',
#  '14248_output.txt',
#  '06678_output.txt',
#  '04605_output.txt',
#  '00193_output.txt',
#  '00034_output.txt',
#  '06439_output.txt',
#  '00196_output.txt',
#  '13975_output.txt',
#  '10762_output.txt',
#  '15045_output.txt',
#  '03601_output.txt',
#  '09863_output.txt',
#  '11957_output.txt',
#  '10133_output.txt',
#  '00099_output.txt',
#  '04610_output.txt',
#  '03904_output.txt',
#  '06903_output.txt',
#  '02798_output.txt',
#  '11086_output.txt',
#  '05755_output.txt',
#  '02743_output.txt',
#  '05831_output.txt',
#  '15696_output.txt',
#  '07755_output.txt',
#  '09027_output.txt',
#  '04654_output.txt',
#  '06308_output.txt',
#  '16259_output.txt',
#  '05440_output.txt',
#  '12223_output.txt',
#  '05377_output.txt',
#  '13895_output.txt',
#  '05979_output.txt',
#  '01487_output.txt',
#  '15233_output.txt',
#  '11122_output.txt',
#  '04433_output.txt',
#  '04196_output.txt',
#  '11925.txt',
#  '11695_output.txt',
#  '05594_output.txt',
#  '03732_output.txt',
#  '09971_output.txt',
#  '12939_output.txt',
#  '01058_output.txt',
#  '04515_output.txt',
#  '03726_output.txt',
#  '10286_output.txt',
#  '08396_output.txt',
#  '01111_output.txt',
#  '04744_output.txt',
#  '11073_output.txt',
#  '15589_output.txt',
#  '03952_output.txt',
#  '12643_output.txt',
#  '08882_output.txt',
#  '13842_output.txt',
#  '09291_output.txt',
#  '15920_output.txt',
#  '00431_output.txt',
#  '13555_output.txt',
#  '10880_output.txt',
#  '10842_output.txt',
#  '01087_output.txt',
#  '12511_output.txt',
#  '01528_output.txt',
#  '03975_output.txt',
#  '05094_output.txt',
#  '09427_output.txt',
#  '13097_output.txt',
#  '16027_output.txt',
#  '15557_output.txt',
#  '13782_output.txt',
#  '15836_output.txt',
#  '11865_output.txt',
#  '15387_output.txt',
#  '11778_output.txt',
#  '16456_output.txt',
#  '15399_output.txt',
#  '11842_output.txt',
#  '10879_output.txt',
#  '07182_output.txt',
#  '10557_output.txt',
#  '14330_output.txt',
#  '04831_output.txt',
#  '05749_output.txt',
#  '05357_output.txt',
#  '16306_output.txt',
#  '11253_output.txt',
#  '15590_output.txt',
#  '09036_output.txt',
#  '03977_output.txt',
#  '03739_output.txt',
#  '14570_output.txt',
#  '04423_output.txt',
#  '01816_output.txt',
#  '05973_output.txt',
#  '01036_output.txt',
#  '11970_output.txt',
#  '05278_output.txt',
#  '04802_output.txt',
#  '09572_output.txt',
#  '13954_output.txt',
#  '01264_output.txt',
#  '08124_output.txt',
#  '07180_output.txt',
#  '07406_output.txt',
#  '08803_output.txt',
#  '01897_output.txt',
#  '12218_output.txt',
#  '03179_output.txt',
#  '02371_output.txt',
#  '11846_output.txt',
#  '10387_output.txt',
#  '06858_output.txt',
#  '07647_output.txt',
#  '01613_output.txt',
#  '06960_output.txt',
#  '07896_output.txt',
#  '15664_output.txt',
#  '00859_output.txt',
#  '07362_output.txt',
#  '00345_output.txt',
#  '03992_output.txt',
#  '06447_output.txt',
#  '06065_output.txt',
#  '16229_output.txt',
#  '02861_output.txt',
#  '02139_output.txt',
#  '12018_output.txt',
#  '11389_output.txt',
#  '00973_output.txt',
#  '03248_output.txt',
#  '04991_output.txt',
#  '14116_output.txt',
#  '11306_output.txt',
#  '06473_output.txt',
#  '15001_output.txt',
#  '14710_output.txt',
#  '15579_output.txt',
#  '05873_output.txt',
#  '02186_output.txt',
#  '14882_output.txt',
#  '13114_output.txt',
#  '10960_output.txt',
#  '15025_output.txt',
#  '15238_output.txt',
#  '15447_output.txt',
#  '15406_output.txt',
#  '04031_output.txt',
#  '02443_output.txt',
#  '12243_output.txt',
#  '01624_output.txt',
#  '15326_output.txt',
#  '06141_output.txt',
#  '12682_output.txt',
#  '04002_output.txt',
#  '13002_output.txt',
#  '04028_output.txt',
#  '01611_output.txt',
#  '01637_output.txt',
#  '09227_output.txt',
#  '06027_output.txt',
#  '10075_output.txt',
#  '01208_output.txt',
#  '05215_output.txt',
#  '06403_output.txt',
#  '00123_output.txt',
#  '15910_output.txt',
#  '07659_output.txt',
#  '05464_output.txt',
#  '14112_output.txt',
#  '08523_output.txt',
#  '04959_output.txt',
#  '06171_output.txt',
#  '07204_output.txt',
#  '08441_output.txt',
#  '13158_output.txt',
#  '00408_output.txt',
#  '05484_output.txt',
#  '01907_output.txt',
#  '10316_output.txt',
#  '00393_output.txt',
#  '11589_output.txt',
#  '14527_output.txt',
#  '05347_output.txt',
#  '06936_output.txt',
#  '09467_output.txt',
#  '12893_output.txt',
#  '14787_output.txt',
#  '03197_output.txt',
#  '07454.txt',
#  '13632_output.txt',
#  '11396_output.txt',
#  '13867_output.txt',
#  '06525_output.txt',
#  '03199_output.txt',
#  '06165_output.txt',
#  '01525_output.txt',
#  '15054_output.txt',
#  '01360_output.txt',
#  '12221_output.txt',
#  '12066_output.txt',
#  '12568_output.txt',
#  '06426_output.txt',
#  '02154_output.txt',
#  '08321_output.txt',
#  '14933_output.txt',
#  '05943_output.txt',
#  '09305_output.txt',
#  '04572_output.txt',
#  '00844_output.txt',
#  '09673_output.txt',
#  '13730_output.txt',
#  '09024_output.txt',
#  '10275_output.txt',
#  '05987_output.txt',
#  '03265_output.txt',
#  '07365_output.txt',
#  '02665_output.txt',
#  '12002_output.txt',
#  '08802_output.txt',
#  '09596_output.txt',
#  '08524_output.txt',
#  '05513_output.txt',
#  '15450_output.txt',
#  '12220.txt',
#  '15626_output.txt',
#  '02195_output.txt',
#  '06740_output.txt',
#  '02294_output.txt',
#  '05388_output.txt',
#  '15989_output.txt',
#  '12194_output.txt',
#  '10131_output.txt',
#  '06572_output.txt',
#  '10031_output.txt',
#  '06584_output.txt',
#  '09733_output.txt',
#  '05575_output.txt',
#  '13280_output.txt',
#  '08909_output.txt',
#  '05847_output.txt',
#  '01164_output.txt',
#  '02492_output.txt',
#  '15861_output.txt',
#  '01108_output.txt',
#  '07427_output.txt',
#  '08253_output.txt',
#  '00769_output.txt',
#  '07913_output.txt',
#  '06606_output.txt',
#  '06135_output.txt',
#  '11196_output.txt',
#  '02901_output.txt',
#  '03834_output.txt',
#  '09094_output.txt',
#  '03316_output.txt',
#  '12449_output.txt',
#  '10254_output.txt',
#  '07975_output.txt',
#  '04414_output.txt',
#  '09540_output.txt',
#  '09247_output.txt',
#  '05073_output.txt',
#  '01521_output.txt',
#  '06056_output.txt',
#  '10033.txt',
#  '01825_output.txt',
#  '00459_output.txt',
#  '06425_output.txt',
#  '14773_output.txt',
#  '01228_output.txt',
#  '01376_output.txt',
#  '00654_output.txt',
#  '07382_output.txt',
#  '05580_output.txt',
#  '00411_output.txt',
#  '04103_output.txt',
#  '01785_output.txt',
#  '14873_output.txt',
#  '04893_output.txt',
#  '10496_output.txt',
#  '00704_output.txt',
#  '13772_output.txt',
#  '10396_output.txt',
#  '13826_output.txt',
#  '10178_output.txt',
#  '05601_output.txt',
#  '02879_output.txt',
#  '00586_output.txt',
#  '07165_output.txt',
#  '00020_output.txt',
#  '09267_output.txt',
#  '03352_output.txt',
#  '08893_output.txt',
#  '11093_output.txt',
#  '14273_output.txt',
#  '08476_output.txt',
#  '12494_output.txt',
#  '06119_output.txt',
#  '06700_output.txt',
#  '04469_output.txt',
#  '03064_output.txt',
#  '00535_output.txt',
#  '05284_output.txt',
#  '05021_output.txt',
#  '13972_output.txt',
#  '15884_output.txt',
#  '13961_output.txt',
#  '01912_output.txt',
#  '09964_output.txt',
#  '06970_output.txt',
#  '10327_output.txt',
#  '06339_output.txt',
#  '13269.txt',
#  '15743_output.txt',
#  '00990_output.txt',
#  '05751_output.txt',
#  '14531_output.txt',
#  '00094_output.txt',
#  '07208_output.txt',
#  '05825_output.txt',
#  '15754_output.txt',
#  '09583_output.txt',
#  '12295_output.txt',
#  '12021_output.txt',
#  '15475_output.txt',
#  '09833_output.txt',
#  '15515_output.txt',
#  '12371_output.txt',
#  '08461_output.txt',
#  '09164_output.txt',
#  '02396_output.txt',
#  '14524_output.txt',
#  '05892_output.txt',
#  '07443_output.txt',
#  '12714_output.txt',
#  '00765_output.txt',
#  '11059_output.txt',
#  '05765_output.txt',
#  '13823_output.txt',
#  '00283_output.txt',
#  '01127_output.txt',
#  '05235_output.txt',
#  '16056_output.txt',
#  '09374_output.txt',
#  '03161_output.txt',
#  '09614_output.txt',
#  '06996_output.txt',
#  '04158_output.txt',
#  '07144_output.txt',
#  ...]

# %%
import os, shutil

shutil.rmtree("field_training/labels")
